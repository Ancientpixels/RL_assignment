# %%
import random
import numpy as np

class StringMatchingGA:
    def __init__(self, target_string, population_size=100, mutation_rate=0.01, crossover_rate=0.7):
        self.target_string = target_string
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.population = self.initialize_population()
    
    def initialize_population(self):
        return [''.join(random.choices('abcdefghijklmnopqrstuvwxyz ', k=len(self.target_string))) for _ in range(self.population_size)]
    
    def fitness(self, individual):
        return sum(1 for a, b in zip(individual, self.target_string) if a == b)
    
    def select_parents(self):
        fitnesses = [self.fitness(ind) for ind in self.population]
        total_fitness = sum(fitnesses)
        selection_probs = [f / total_fitness for f in fitnesses]
        return random.choices(self.population, weights=selection_probs, k=2)
    
    def crossover(self, parent1, parent2):
        if random.random() < self.crossover_rate:
            crossover_point = random.randint(1, len(self.target_string) - 1)
            child1 = parent1[:crossover_point] + parent2[crossover_point:]
            child2 = parent2[:crossover_point] + parent1[crossover_point:]
            return child1, child2
        return parent1, parent2
    
    def mutate(self, individual):
        return ''.join(c if random.random() > self.mutation_rate else random.choice('abcdefghijklmnopqrstuvwxyz ') for c in individual)
    
    def evolve(self):
        new_population = []
        while len(new_population) < self.population_size:
            parent1, parent2 = self.select_parents()
            child1, child2 = self.crossover(parent1, parent2)
            new_population.append(self.mutate(child1))
            new_population.append(self.mutate(child2))
        self.population = new_population
    
    def run(self, generations=100):
        for generation in range(generations):
            self.evolve()
            best_individual = max(self.population, key=self.fitness)
            best_fitness = self.fitness(best_individual)
            print(f"Generation {generation}: Best Individual = {best_individual}, Fitness = {best_fitness}")
            if best_fitness == len(self.target_string):
                print("Target string matched!")
                break

# %%
class RLAgent:
    def __init__(self, state_space, action_space, learning_rate=0.1, discount_factor=0.99, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01):
        self.state_space = state_space
        self.action_space = action_space
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.Q = {}
    
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.choice(self.action_space)
        else:
            return self.get_best_action(state)
    
    def get_best_action(self, state):
        if state not in self.Q:
            self.Q[state] = np.zeros(len(self.action_space))
        return np.argmax(self.Q[state])
    
    def update_q_value(self, state, action, reward, next_state):
        if state not in self.Q:
            self.Q[state] = np.zeros(len(self.action_space))
        if next_state not in self.Q:
            self.Q[next_state] = np.zeros(len(self.action_space))
        
        best_next_action = self.get_best_action(next_state)
        td_target = reward + self.discount_factor * self.Q[next_state][best_next_action]
        td_error = td_target - self.Q[state][action]
        self.Q[state][action] += self.learning_rate * td_error
    
    def decay_epsilon(self):
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

# %%
def train_rl_agent(agent, ga, episodes=100):
    for episode in range(episodes):
        state = (ga.mutation_rate, ga.crossover_rate)
        action = agent.get_action(state)
        
        new_mutation_rate = max(0.01, min(0.1, ga.mutation_rate + (action % 3 - 1) * 0.01))
        new_crossover_rate = max(0.5, min(0.9, ga.crossover_rate + (action // 3 - 1) * 0.1))
        
        ga.mutation_rate = new_mutation_rate
        ga.crossover_rate = new_crossover_rate
        
        ga.run(generations=10)
        
        best_fitness = max(ga.fitness(ind) for ind in ga.population)
        reward = best_fitness
        
        next_state = (ga.mutation_rate, ga.crossover_rate)
        agent.update_q_value(state, action, reward, next_state)
        agent.decay_epsilon()
        
        print(f"Episode {episode}: Mutation Rate = {ga.mutation_rate}, Crossover Rate = {ga.crossover_rate}, Best Fitness = {best_fitness}")

target_string = "hello world"
ga = StringMatchingGA(target_string)
agent = RLAgent(state_space=1000, action_space=list(range(9)))  

train_rl_agent(agent, ga)
# Out:
# Generation 0: Best Individual = zealovzvuns, Fitness = 3
# Generation 1: Best Individual =  eckbkwahlq, Fitness = 3
# Generation 2: Best Individual = hgugooeihlq, Fitness = 3
# Generation 3: Best Individual = bxalpmwollq, Fitness = 4
# Generation 4: Best Individual = hxtlovzdulz, Fitness = 4
# Generation 5: Best Individual = hxtlovgjrli, Fitness = 5
# Generation 6: Best Individual = hxtlovgjrli, Fitness = 5
# Generation 7: Best Individual = hxalozwollq, Fitness = 6
# Generation 8: Best Individual = hxalozwollq, Fitness = 6
# Generation 9: Best Individual = hxtlozwollq, Fitness = 6
# Episode 0: Mutation Rate = 0.01, Crossover Rate = 0.7, Best Fitness = 6
# Generation 0: Best Individual = healomwmrlz, Fitness = 7
# Generation 1: Best Individual = hhmlo uorli, Fitness = 7
# Generation 2: Best Individual = hhmlo uorlw, Fitness = 7
# Generation 3: Best Individual = hhmlo uorlw, Fitness = 7
# Generation 4: Best Individual = we lo worlj, Fitness = 8
# Generation 5: Best Individual = he lo uorlw, Fitness = 8
# Generation 6: Best Individual = he lo uorlz, Fitness = 8
# Generation 7: Best Individual = he lo uorlz, Fitness = 8
# Generation 8: Best Individual = he lo uorlz, Fitness = 8
# Generation 9: Best Individual = healo qorli, Fitness = 8
# Episode 1: Mutation Rate = 0.01, Crossover Rate = 0.7999999999999999, Best Fitness = 8
# Generation 0: Best Individual = heilo uorlz, Fitness = 8
# Generation 1: Best Individual = healo worli, Fitness = 9
# Generation 2: Best Individual = heilo uorli, Fitness = 8
# Generation 3: Best Individual = he lo uorlz, Fitness = 8
# Generation 4: Best Individual = hemlo uorlq, Fitness = 8
# Generation 5: Best Individual = heilo qorlw, Fitness = 8
# Generation 6: Best Individual = heilo uorlf, Fitness = 8
# Generation 7: Best Individual = he lo wmrli, Fitness = 8
# Generation 8: Best Individual = he lo worlf, Fitness = 9
# Generation 9: Best Individual = healo worlf, Fitness = 9
# Episode 2: Mutation Rate = 0.01, Crossover Rate = 0.7, Best Fitness = 9
# Generation 0: Best Individual = he lo worlf, Fitness = 9
# Generation 1: Best Individual = healo worlf, Fitness = 9
# Generation 2: Best Individual = healo worlf, Fitness = 9
# Generation 3: Best Individual = healo worlf, Fitness = 9
# Generation 4: Best Individual = heblo worlv, Fitness = 9
# Generation 5: Best Individual = healo worlf, Fitness = 9
# Generation 6: Best Individual = he lo worlf, Fitness = 9
# Generation 7: Best Individual = heilo worlp, Fitness = 9
# Generation 8: Best Individual = he lo worli, Fitness = 9
# Generation 9: Best Individual = he lo worlf, Fitness = 9
# Episode 3: Mutation Rate = 0.01, Crossover Rate = 0.7, Best Fitness =
Mutation Rate = 0.02, Crossover Rate = 0.5, Best Fitness = 10
# Generation 0: Best Individual = herlo world, Fitness = 10
# Generation 1: Best Individual = herlo world, Fitness = 10
# Generation 2: Best Individual = hemlo world, Fitness = 10
# Generation 3: Best Individual = hellobworld, Fitness = 10
# Generation 4: Best Individual = hemlo world, Fitness = 10
# Generation 5: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 27: Mutation Rate = 0.02, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = heplo world, Fitness = 10
# Generation 1: Best Individual = henlo world, Fitness = 10
# Generation 2: Best Individual = herlo world, Fitness = 10
# Generation 3: Best Individual = herlo world, Fitness = 10
# Generation 4: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 28: Mutation Rate = 0.02, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 29: Mutation Rate = 0.01, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 30: Mutation Rate = 0.01, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 31: Mutation Rate = 0.01, Crossover Rate = 0.7, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 32: Mutation Rate = 0.01, Crossover Rate = 0.7999999999999999, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 33: Mutation Rate = 0.02, Crossover Rate = 0.8999999999999999, Best Fitness = 11
# Generation 0: Best Individual = herlo world, Fitness = 10
# Generation 1: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 34: Mutation Rate = 0.02, Crossover Rate = 0.9, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 35: Mutation Rate = 0.02, Crossover Rate = 0.8, Best Fitness = 11
# Generation 0: Best Individual = herlo world, Fitness = 10
# Generation 1: Best Individual = herlo world, Fitness = 10
# Generation 2: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 36: Mutation Rate = 0.03, Crossover Rate = 0.9, Best Fitness = 11
# Generation 0: Best Individual = herlo world, Fitness = 10
# Generation 1: Best Individual = hemlo world, Fitness = 10
# Generation 2: Best Individual = hemlo world, Fitness = 10
# Generation 3: Best Individual = herlo world, Fitness = 10
# Generation 4: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 37: Mutation Rate = 0.019999999999999997, Crossover Rate = 0.9, Best Fitness = 11
# Generation 0: Best Individual = herlo world, Fitness = 10
# Generation 1: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 38: Mutation Rate = 0.03, Crossover Rate = 0.8, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 39: Mutation Rate = 0.019999999999999997, Crossover Rate = 0.7000000000000001, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 40: Mutation Rate = 0.01, Crossover Rate = 0.8, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 41: Mutation Rate = 0.02, Crossover Rate = 0.9, Best Fitness = 11
# Generation 0: Best Individual = herlo world, Fitness = 10
# Generation 1: Best Individual = heloo world, Fitness = 10
# Generation 2: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 42: Mutation Rate = 0.02, Crossover Rate = 0.8, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 43: Mutation Rate = 0.03, Crossover Rate = 0.9, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 44: Mutation Rate = 0.04, Crossover Rate = 0.9, Best Fitness = 11
# Generation 0: Best Individual = aello world, Fitness = 10
# Generation 1: Best Individual = herlo world, Fitness = 10
# Generation 2: Best Individual = cello world, Fitness = 10
# Generation 3: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 45: Mutation Rate = 0.03, Crossover Rate = 0.8, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 46: Mutation Rate = 0.019999999999999997, Crossover Rate = 0.7000000000000001, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 47: Mutation Rate = 0.01, Crossover Rate = 0.8, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 48: Mutation Rate = 0.01, Crossover Rate = 0.7000000000000001, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 49: Mutation Rate = 0.01, Crossover Rate = 0.7000000000000001, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 50: Mutation Rate = 0.01, Crossover Rate = 0.6000000000000001, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 51: Mutation Rate = 0.01, Crossover Rate = 0.5000000000000001, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 52: Mutation Rate = 0.01, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 53: Mutation Rate = 0.01, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 54: Mutation Rate = 0.02, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 55: Mutation Rate = 0.02, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 56: Mutation Rate = 0.02, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 57: Mutation Rate = 0.02, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 58: Mutation Rate = 0.01, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 59: Mutation Rate = 0.01, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 60: Mutation Rate = 0.01, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 61: Mutation Rate = 0.01, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 62: Mutation Rate = 0.01, Crossover Rate = 0.7, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 63: Mutation Rate = 0.01, Crossover Rate = 0.7999999999999999, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 64: Mutation Rate = 0.01, Crossover Rate = 0.8999999999999999, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 65: Mutation Rate = 0.01, Crossover Rate = 0.7999999999999999, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 66: Mutation Rate = 0.02, Crossover Rate = 0.7999999999999999, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 67: Mutation Rate = 0.01, Crossover Rate = 0.7, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 68: Mutation Rate = 0.01, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 69: Mutation Rate = 0.01, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 70: Mutation Rate = 0.02, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 71: Mutation Rate = 0.02, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 72: Mutation Rate = 0.02, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 73: Mutation Rate = 0.03, Crossover Rate = 0.7, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 74: Mutation Rate = 0.019999999999999997, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 75: Mutation Rate = 0.01, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 76: Mutation Rate = 0.02, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 77: Mutation Rate = 0.02, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 78: Mutation Rate = 0.02, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 79: Mutation Rate = 0.02, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 80: Mutation Rate = 0.03, Crossover Rate = 0.7, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 81: Mutation Rate = 0.019999999999999997, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 82: Mutation Rate = 0.01, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 83: Mutation Rate = 0.02, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 84: Mutation Rate = 0.01, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 85: Mutation Rate = 0.01, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 86: Mutation Rate = 0.01, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 87: Mutation Rate = 0.01, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 88: Mutation Rate = 0.01, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 89: Mutation Rate = 0.01, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 90: Mutation Rate = 0.02, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 91: Mutation Rate = 0.02, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 92: Mutation Rate = 0.02, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 93: Mutation Rate = 0.01, Crossover Rate = 0.5, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 94: Mutation Rate = 0.01, Crossover Rate = 0.6, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 95: Mutation Rate = 0.01, Crossover Rate = 0.7, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 96: Mutation Rate = 0.01, Crossover Rate = 0.7999999999999999, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 97: Mutation Rate = 0.02, Crossover Rate = 0.7999999999999999, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 98: Mutation Rate = 0.01, Crossover Rate = 0.7, Best Fitness = 11
# Generation 0: Best Individual = hello world, Fitness = 11
# Target string matched!
# Episode 99: Mutation Rate = 0.01, Crossover Rate = 0.7999999999999999, Best Fitness = 11
